# %% [markdown]
# <a href="https://colab.research.google.com/github/MohdAffan27/AI-Learning-Journey/blob/main/04_MATPLOTLIB/Matplotlib_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Matplotlib
#   Matplotlib is a Python library for creating static, interactive and animated visualizations from data. It provides flexible and customizable plotting functions that help in understanding data patterns, trends and relationships effectively.
#
#
#
#
# ---

# %% [markdown]
# ![SS.png](data:image/png;base64,...)

# %% [markdown]
# #####Example:
# Let's create a simple line plot using Matplotlib, showcasing the ease with which you can visualize data.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.lines import lineStyles


x = np.array([1,2,3])
y = np.array([4,5,6])

plt.plot(x,y)
plt.grid()
plt.show()

# %% [markdown]
# ### -> Matplotlib Pyplot
# Pyplot is a module within Matplotlib that provides a MATLAB-like interface for making plots. It simplifies the process of adding plot elements such as lines, images and text to the axes of the current figure.

# %% [markdown]
# #####Steps to Use Pyplot:
#         * Import Matplotlib: Start by importing matplotlib.pyplot as plt.
#         * Create Data: Prepare your data in the form of lists or arrays.
#         * Plot Data: Use plt.plot() to create the plot.
#         * Customize Plot: Add titles, labels and other elements using methods like plt.title(), plt.xlabel() and plt.ylabel().
#         * Display Plot: Use plt.show() to display the plot.

# %% [markdown]
# # Different Types of Plots in Matplotlib
#
#
# ---
#
#
# ### Type 1. ***Univariate Analysis***
#
#
# ---
#
#
# Visualize only one column of data at the same time on a single graph.
#
# -> Numerical Data
#
# 1. Line plot / Line Chart
#
#
# *   Line chart is one of the basic plots and can be created using plot() function.
# *   It is used to represent a relationship between two data X and Y on a different axis.
# *   It is commonly used to visualize trends, changes, or patterns in data over a sequence, such as days, months, or years. Line charts make it easy to compare values and observe how data changes over time.

# %%
data = {
    "salaries": [45000, 46639, 48000, 51717, 52000, 52296, 54144, 59628, 60000, 61049, 63024, 71000, 80741, 85000, 86905, 89348, 92000, 93265, 93540, 93598]
}

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    salaries
# 0     45000
# 1     46639
# 2     48000
# 3     51717
# 4     52000

# %%
df.shape
# Out:
# (20, 1)

# %%
#line plot
plt.plot(df['salaries'], color= "red", marker = "o", linestyle = ":", linewidth= 2)
plt.grid()
plt.show()

# %% [markdown]
# When you pass a single column or a 1D array to plt.plot() without providing an explicit x-variable, Matplotlib automatically defaults to using the index (0, 1, 2, etc., or your custom index labels) for the horizontal x-axis.

# %% [markdown]
# ---
#
#
# 2. Histogram
#
# * Histogram shows the distribution of data by grouping values into bins.
# * The hist() function is used to create it, with X-axis showing bins and Y-axis showing frequencies.

# %%
plt.hist(df, bins=10, color='steelblue')
plt.title("Histogram")
plt.xlabel("Salaries")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Histogram with Density Curve
#
#     A density curve can be added to a histogram to visualize the overall distribution of the data along with the frequency of
#     values. This provides a smoother view of the data pattern.

# %% [markdown]
# 2D Histogram (Hexbin Plot)
#
#     A 2D histogram groups data into hexagonal bins to show the density of points across two variables.
#     It is useful for visualizing large datasets where many points overlap in a scatter plot.

# %%
x = np.random.randn(1000)
y = 2 * x + np.random.normal(size=1000)

plt.hexbin(x, y, gridsize=30, cmap='Blues')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('2D Histogram (Hexbin Plot)')
plt.colorbar(label='Counts')
plt.show()

# %% [markdown]
# ---
# 3. Box Plot
#
#
#
# * Box plot is a simple graph that shows how data is spread out.
# * It displays the minimum, maximum, median and quartiles and also helps to spot outliers easily.

# %%
plt.boxplot(df['salaries'] )
plt.show()

# %%
df.loc[20]=[0]

# %%
plt.boxplot(df['salaries'] )
plt.show()

# %%
df.drop(20, inplace=True)

# %%
df.shape
# Out:
# (20, 1)

# %% [markdown]
# ---
#
#
# -> Categorical Data
#
#
# ---

# %%
df["dept"] = ['HR','IT','Finance','HR','IT','Finance','HR','IT','Finance','HR','IT','Finance','HR','IT','Finance','HR','IT','Finance','IT','Finance']

# %%
df.head()
# Out:
#    salaries     dept
# 0     45000       HR
# 1     46639       IT
# 2     48000  Finance
# 3     51717       HR
# 4     52000       IT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   salaries  20 non-null     int64
#  1   dept      20 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 480.0+ bytes

# %% [markdown]
# 4. Pie Chart
# * Pie chart is a circular chart used to show data as proportions or percentages.
# * It is created using the pie(), where each slice (wedge) represents a part of the whole.

# %%
count = df["dept"].value_counts()
count
# Out:
# dept
# IT         7
# Finance    7
# HR         6
# Name: count, dtype: int64

# %%
plt.pie(count, labels=count.index, autopct="%1.1f%%")
plt.show()

# %% [markdown]
# To represent the particular Data

# %%
plt.pie(count, labels=count.index, autopct="%1.1f%%", explode=[0, 0.1, 0])
plt.axis('equal')
plt.show()

# %% [markdown]
# ---
#
#
# 5. Bar Chart/Count Plot
#
#
# *   It counts items in groups: It is a bar chart that displays how many times each item or category appears in your data.
# *   It does the math for you: You only give it one column (like "City" or "Color"), and it automatically counts the totals and draws the bars.

# %%
plt.bar(count.index, count, color = ["green", "brown" , "red"])
plt.grid()
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
# ### Type 2. ***Bivariate Analysis***
# Visualize only two columns of data at the same time on a single graph.
#
# -> Numerical : Numerical
#
# ---

# %% [markdown]
# 6. Scattered plot

# %%
df.head()
# Out:
#    salaries     dept
# 0     45000       HR
# 1     46639       IT
# 2     48000  Finance
# 3     51717       HR
# 4     52000       IT

# %%
df["Age"] = [23, 45, 31, 19, 52, 28, 41, 36, 60, 22, 25, 34, 47, 50, 29, 33, 58, 42, 26, 31]

# %%
df.head()
# Out:
#    salaries     dept  Age
# 0     45000       HR   23
# 1     46639       IT   45
# 2     48000  Finance   31
# 3     51717       HR   19
# 4     52000       IT   52

# %%
sort_Age = df.sort_values("Age")

# %%
plt.scatter(sort_Age["Age"], df["salaries"], color = "red")
plt.grid()
plt.show()

# %% [markdown]
# -> Line plot(Working with Bivariate Data)

# %%
plt.plot(sort_Age["Age"], df["salaries"], color = "red", marker= "o", linewidth= 2)
plt.grid()
plt.show()

# %% [markdown]
# Multiple Plots on Same Axis

# %%
x = np.array([1, 2, 3, 4])
y = x * 2

x1 = [2, 4, 6, 8]
y1 = [3, 5, 7, 9]

plt.plot(x, y, label='y = 2x')
plt.plot(x1, y1, '-.', label='Second Line')

plt.xlabel("X-axis data")
plt.ylabel("Y-axis data")
plt.title("Multiple Plots on Same Axis")
plt.legend()
plt.show()

# %% [markdown]
# Fill Area Between Two Lines

# %%
x = np.array([1, 2, 3, 4])
y = x * 2
y1 = [3, 5, 7, 9]

plt.plot(x, y, label='y = 2x')
plt.plot(x, y1, '-.', label='y1')
plt.fill_between(x, y, y1, color='yellow', alpha=0.4)

plt.xlabel("X-axis data")
plt.ylabel("Y-axis data")
plt.title("Filled Area Between Two Lines")
plt.legend()
plt.show()

# %% [markdown]
# Plotting Trigonometric Functions

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 100)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.plot(x, y_sin, label="sin(x)")
plt.plot(x, y_cos, label="cos(x)")
plt.xlabel("X values")
plt.ylabel("Function value")
plt.title("Trigonometric Functions")
plt.legend()
plt.show()

# %% [markdown]
# ---
#
#
# -> Bar Chart(Working with Bivariate Data)

# %%
plt.bar(sort_Age["Age"], df["salaries"], color = "green", align="edge")
plt.show()

# %% [markdown]
# Adding value labels on a Matplotlib Bar Chart
#
#     add_labels(x, y) function adds numerical labels above each bar by iterating through the data and using plt.text(i, y[i], y[i]) to position values at their respective heights.
#     By default, labels are center-aligned for clarity.

# %%
# Function to add centered value labels
def add_labels(x, y):
    for i in range(len(x)):
        plt.text(i, y[i] // 2, y[i], ha='center')  # # Placing text at half the bar height & Aligning text at center

x = ["Engineering", "BSc", "MBA", "Bcom", "BBA", "MSc"]
y = [9330, 4050, 3030, 5500, 8040, 4560]

# Setting figure size
plt.figure(figsize=(10, 5))

# Creating bar chart
plt.bar(x, y)

# Adding value labels
add_labels(x, y)

# Adding title and labels
plt.title("College Admission")
plt.xlabel("Courses")
plt.ylabel("Number of Admissions")

plt.show()

# %% [markdown]
# ---
#
# -> Numerical : Categorical
#
#
# ---

# %%
# hr Salary analysis
hr_sal = df[df["dept"]=="HR"]["salaries"]
hr_sal
# Out:
# 0     45000
# 3     51717
# 6     54144
# 9     61049
# 12    80741
# 15    89348
# Name: salaries, dtype: int64

# %%
# it salary analysis
it_sal = df[df["dept"]=="IT"]["salaries"]
it_sal
# Out:
# 1     46639
# 4     52000
# 7     59628
# 10    63024
# 13    85000
# 16    92000
# 18    93540
# Name: salaries, dtype: int64

# %%
# finance salary analysis
fin_sal = df[df["dept"]=="Finance"]["salaries"]
fin_sal
# Out:
# 2     48000
# 5     52296
# 8     60000
# 11    71000
# 14    86905
# 17    93265
# 19    93598
# Name: salaries, dtype: int64

# %% [markdown]
# -> *boxplot*

# %%
plt.boxplot([hr_sal, it_sal, fin_sal], tick_labels=["HR", "IT", "Finance"])
# plt.legend()
plt.show()

# %% [markdown]
# *->pie chart*

# %%
salary_by_dept = df.groupby("dept")["salaries"].sum()
salary_by_dept
# Out:
# dept
# Finance    505064
# HR         381999
# IT         491831
# Name: salaries, dtype: int64

# %%
plt.pie(salary_by_dept, labels=salary_by_dept.index, autopct="%1.2f",shadow=True ,explode=[0.1, 0.1, 0.1], startangle=10)
plt.axis("equal")
plt.show()

# %% [markdown]
# *->Bar plot*

# %%
hr_mean = sum(hr_sal)/len(hr_sal)
it_mean = sum(it_sal)/len(it_sal)
fin_mean = sum(fin_sal)/len(fin_sal)

# %%
plt.bar(["HR","IT","Fianance"],[hr_mean,it_mean,fin_mean],color = ["green","brown","pink"])
plt.grid()
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
# ### Type 3. *Multivariate Analysis*
#
# visualize three or more columns of data at the same time on a single graph.

# %% [markdown]
# -> 3 numerical column

# %%
df.head()
# Out:
#    salaries     dept  Age
# 0     45000       HR   23
# 1     46639       IT   45
# 2     48000  Finance   31
# 3     51717       HR   19
# 4     52000       IT   52

# %%
df["Experience"] = [0.5, 0.8, 1.2, 1.5, 2.0, 2.7, 3.1, 3.4, 4.0, 5.1, 5.5, 6.0, 6.8, 7.2, 8.5, 9.3, 10.0, 11.0, 12.5, 14.2]

# %%
df.head()
# Out:
#    salaries     dept  Age  Experience
# 0     45000       HR   23         0.5
# 1     46639       IT   45         0.8
# 2     48000  Finance   31         1.2
# 3     51717       HR   19         1.5
# 4     52000       IT   52         2.0

# %% [markdown]
# -> scatter plot / bubble plot

# %%
plt.scatter(sort_Age["Age"], df["salaries"], s=df["Experience"]*50,color="skyblue", edgecolors="darkblue", alpha=0.75)
plt.title("Experience vs salary vs age")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# -> 2 numerical columns and 1 categorical column

# %%
plt.scatter(df["Age"], df["salaries"], c=df["dept"].map({"HR":"green","IT":"red","Finance":"blue"}), label=("HR", "IT","Finance" ))
plt.title("Experience vs salary vs age")
plt.xlabel("Age")
plt.ylabel("Salary")
# plt.legend()
plt.show()

# %%
color = {"HR":"green","IT":"red","Finance":"blue"}

for dept, color in color.items():
  df_dept = df[df["dept"]==dept]
  plt.scatter(df_dept["Age"], df_dept["salaries"], c=color, label=dept)
plt.legend()
plt.title("Experience vs salary vs age")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ---
#
#
# ### Object oriented Api
#
#
# ---

# %%
fig , axs =plt.subplots(1,3, figsize=(15,5))

#line plot

axs[0].plot(sort_Age["Age"], df["salaries"], color = "red", marker= "o", linewidth= 2)
axs[0].grid()
axs[0].set_title("Line plot")
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Salary")

#Histogram
axs[1].hist(df["salaries"],bins=5, color = "brown")
axs[1].set_title("Histogram")
axs[1].set_xlabel("Salaries")
axs[1].set_ylabel("Frequency")

#Box plot
axs[2].boxplot(df['salaries'] )
axs[2].set_title("Box plot")
axs[2].set_xlabel("Salaries")

# plt.savefig("Multiple_plot.jpg")
plt.show()

# %% [markdown]
# ---
#
#
# ####-> Multiple plot

# %%
data2 = {
    'Year': [2022, 2023, 2024, 2025],
    'Sales':[100, 150, 200, 250],
    'Profit':[20, 30, 40, 50],
    'Expenses': [80, 120, 160, 200]
}

# %%
df2 = pd.DataFrame(data2)

# %%
plt.plot(df2['Year'], df2['Sales'], label='Sales')
plt.plot(df2['Year'], df2['Profit'], label='Profit')
plt.plot(df2['Year'], df2['Expenses'], label='Expenses')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.title('Financial Analysis')
plt.legend()
plt.show()

# %% [markdown]
# Creating Subplots for Different Mathematical Functions
#
#     The following example creates a 2x2 grid and plots the sine, cosine, tangent, and sinc functions with different line styles and colors.

# %%
# Creating subplots
fig, ax = plt.subplots(2, 2)

# Generating data
x = np.linspace(0, 10, 1000)

# Plot functions with different styles
ax[0, 0].plot(x, np.sin(x), 'r-.', label='sin(x)')
ax[0, 1].plot(x, np.cos(x), 'g--', label='cos(x)')
ax[1, 0].plot(x, np.tan(x), 'y-', label='tan(x)')
ax[1, 1].plot(x, np.sinc(x), 'c.-', label='sinc(x)')

# Adding legends and showing the figure
for axes in ax.flat:
    axes.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### 3D analysis

# %%
df.head()
# Out:
#    salaries     dept  Age  Experience
# 0     45000       HR   23         0.5
# 1     46639       IT   45         0.8
# 2     48000  Finance   31         1.2
# 3     51717       HR   19         1.5
# 4     52000       IT   52         2.0

# %%
ax = plt.axes(projection = "3d")
ax.scatter3D(df["Age"], df["salaries"], df["Experience"], color= "brown")
ax.set_xlabel("Age")
ax.set_ylabel("Salary")
ax.set_zlabel("Experience")
plt.show()

# %%
import plotly.express as px
fig = px.scatter_3d(df, x="Age", y="salaries", z="Experience", color="dept", title="3D Scattered plot")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
import plotly.express as px

# 1. Generate the data using NumPy
z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

# 2. Build the interactive 3D line plot using Express
fig = px.line_3d( x=x, y=y, z=z)

# 3. Update line properties (optional: matching your 'green' color)
fig.update_traces(line=dict(color='green', width=4))

# 4. Display the fully interactive 3D plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ---
# #### Multiple Charts

# %%
x = np.array([1, 2, 3, 4])
y = x * 2

plt.plot(x, y)
plt.title("First Analysis")
plt.show()

plt.figure()
x1 = [2, 4, 6, 8]
y1 = [3, 5, 7, 9]
plt.scatter(x, y, color = "red")
plt.title("Second Analysis")
plt.grid()
plt.show()

plt.figure()
plt.boxplot([hr_sal, it_sal, fin_sal], tick_labels=["HR", "IT", "Finance"])
plt.title("Third Analysis")
plt.show()
